# %% [markdown]
#                             Questions And Answers

# %% [markdown]
# #1.What is Simple Linear Regression?
# ans:-Simple Linear Regression (SLR) is a statistical method used to model the relationship between two variables:
#
# One independent variable (predictor or input, usually denoted
# 𝑋
# X)
#
# One dependent variable (response or output, usually denoted
# 𝑌
# Y)
#
# The goal is to find a linear equation that best describes how
# 𝑌
# Y changes as
# 𝑋
# X changes.
#
# 🔹 The Model
#
# The relationship is expressed as:
#
# 𝑌
# =
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑋
# +
# 𝜀
# Y=β
# 0
# 	​
#
# +β
# 1
# 	​
#
# X+ε
#
# Where:
#
# 𝑌
# Y: Dependent (response) variable
#
# 𝑋
# X: Independent (predictor) variable
#
# 𝛽
# 0
# β
# 0
# 	​
#
# : Intercept (value of
# 𝑌
# Y when
# 𝑋
# =
# 0
# X=0)
#
# 𝛽
# 1
# β
# 1
# 	​
#
# : Slope (how much
# 𝑌
# Y changes for each unit change in
# 𝑋
# X)
#
# 𝜀
# ε: Error term (difference between the predicted and actual
# 𝑌
# Y)
#
# 🔹 Objective
#
# Find the best-fitting line — often called the regression line — that minimizes the sum of squared differences between observed and predicted values of
# 𝑌
# Y.
# This is done using the Least Squares Method.
#
# 🔹 Example
#
# Suppose you want to predict a student’s exam score (
# 𝑌
# Y) based on their study hours (
# 𝑋
# X).
#
# You might find:
#
# Exam Score
# =
# 40
# +
# 5
# ×
# (
# Study Hours
# )
# Exam Score=40+5×(Study Hours)
#
# This means:
#
# A student who studies 0 hours is expected to score 40 (intercept).
#
# For each additional hour studied, the score increases by 5 points (slope).
#
# 🔹 Assumptions of Simple Linear Regression
#
# Linearity – The relationship between
# 𝑋
# X and
# 𝑌
# Y is linear.
#
# Independence – Observations are independent of each other.
#
# Homoscedasticity – The variance of residuals is constant across all levels of
# 𝑋
# X.
#
# Normality – Residuals are normally distributed.

# %% [markdown]
# #2. What are the key assumptions of Simple Linear Regression?
# ans:-The key assumptions of Simple Linear Regression (SLR) are important conditions that ensure the model gives reliable and valid results. Here are the main ones:
#
# 🔹 1. Linearity
#
# The relationship between the independent variable (X) and the dependent variable (Y) must be linear.
#
# This means that a change in
# 𝑋
# X results in a proportional change in
# 𝑌
# Y.
# ✅ Check: A scatterplot of
# 𝑋
# X vs
# 𝑌
# Y should look roughly like a straight line.
#
# 🔹 2. Independence of Errors
#
# The residuals (errors) — the differences between observed and predicted values — should be independent of each other.
#
# In other words, one observation’s error should not affect another’s.
# ✅ Check: Residuals should show no pattern when plotted in the order of data collection (important in time series).
#
# 🔹 3. Homoscedasticity (Constant Variance)
#
# The variance of residuals should be constant across all values of
# 𝑋
# X.
#
# If residuals fan out or narrow as
# 𝑋
# X increases, this indicates heteroscedasticity, violating the assumption.
# ✅ Check: A residuals vs. fitted values plot should show a random scatter (no funnel shape).
#
# 🔹 4. Normality of Errors
#
# The residuals should be normally distributed.
#
# This is especially important for constructing confidence intervals and hypothesis tests.
# ✅ Check: Use a histogram or Q–Q plot of residuals to assess normality.
#
# 🔹 5. No (or Minimal) Measurement Error in X
#
# The independent variable
# 𝑋
# X should be measured accurately and without error.
#
# Errors in
# 𝑋
# X can bias the estimated slope (
# 𝛽
# 1
# β
# 1
# 	​
#
# ).
#
# ✅ Summary Table
# Assumption	Description	How to Check
# Linearity
# 𝑋
# X and
# 𝑌
# Y have a straight-line relationship	Scatterplot
# Independence	Residuals are independent	Durbin–Watson test, residual plot
# Homoscedasticity	Equal variance of residuals	Residuals vs. fitted plot
# Normality	Residuals are normally distributed	Histogram, Q–Q plot
# No error in X
# 𝑋
# X measured accurately	Data collection checks

# %% [markdown]
# #3.What is heteroscedasticity, and why is it important to address in regression models?
# ans:-Heteroscedasticity is a key concept in regression analysis — and understanding it is essential for building reliable models. Let’s break it down clearly:
#
# 🔹 Definition
#
# Heteroscedasticity occurs when the variance of the residuals (errors) is not constant across all levels of the independent variable(s).
#
# In simpler terms:
#
# The “spread” of the errors changes as
# 𝑋
# X changes.
#
# Some parts of the data show large errors, while others show small errors.
#
# 🔹 Visual Example
#
# If you plot residuals vs. fitted values, you might see:
#
# Homoscedasticity (good):
# The points are evenly scattered (constant spread).
#
# Heteroscedasticity (problematic):
# The points form a funnel shape (spread widens or narrows).
#
# 📉 Example:
# Imagine predicting income based on years of education.
#
# People with fewer years of education might have similar (low) incomes → small residuals.
#
# People with many years of education might have widely varying incomes → large residuals.
# That’s heteroscedasticity.
#
# 🔹 Why It’s Important
#
# Heteroscedasticity does not bias the regression coefficients (
# 𝛽
# 0
# ,
# 𝛽
# 1
# β
# 0
# 	​
#
# ,β
# 1
# 	​
#
# ),
# but it does affect statistical inference — meaning your tests and confidence intervals become unreliable.
#
# Here’s how:
#
# Effect	Explanation
# ⚠️ Inefficient estimates	Ordinary Least Squares (OLS) assumes equal error variance; heteroscedasticity breaks that assumption, making estimates less precise.
# 📉 Incorrect standard errors	Standard errors may be underestimated or overestimated.
# ❌ Invalid hypothesis tests	t-tests and F-tests can give misleading p-values, leading to wrong conclusions about significance.
# 🎯 Biased confidence intervals	Confidence intervals for coefficients become too narrow or too wide.
# 🔹 How to Detect Heteroscedasticity
#
# Visual Inspection
#
# Plot residuals vs. fitted values → look for funnel or wave patterns.
#
# Statistical Tests
#
# Breusch–Pagan test
#
# White’s test
#
# Goldfeld–Quandt test
#
# 🔹 How to Fix or Address It
# Approach	Description
# Transform the dependent variable	Apply log, square root, or Box–Cox transformation to stabilize variance.
# Use weighted least squares (WLS)	Assign smaller weights to observations with higher variance.
# Use robust standard errors	e.g., Huber–White (heteroscedasticity-consistent) standard errors. These don’t fix heteroscedasticity but make inference valid.

# %% [markdown]
# #4.: What is Multiple Linear Regression?
# ans:-Multiple Linear Regression (MLR) is an extension of Simple Linear Regression that allows you to model the relationship between one dependent variable and two or more independent variables.
#
# It helps you understand how multiple factors together influence a single outcome.
#
# 🔹 Definition
#
# The general form of a multiple linear regression model is:
#
# 𝑌
# =
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑋
# 1
# +
# 𝛽
# 2
# 𝑋
# 2
# +
# ⋯
# +
# 𝛽
# 𝑝
# 𝑋
# 𝑝
# +
# 𝜀
# Y=β
# 0
# 	​
#
# +β
# 1
# 	​
#
# X
# 1
# 	​
#
# +β
# 2
# 	​
#
# X
# 2
# 	​
#
# +⋯+β
# p
# 	​
#
# X
# p
# 	​
#
# +ε
#
# Where:
#
# 𝑌
# Y: Dependent (response) variable
#
# 𝑋
# 1
# ,
# 𝑋
# 2
# ,
# …
# ,
# 𝑋
# 𝑝
# X
# 1
# 	​
#
# ,X
# 2
# 	​
#
# ,…,X
# p
# 	​
#
# : Independent (predictor) variables
#
# 𝛽
# 0
# β
# 0
# 	​
#
# : Intercept (value of
# 𝑌
# Y when all
# 𝑋
# 𝑖
# =
# 0
# X
# i
# 	​
#
# =0)
#
# 𝛽
# 1
# ,
# 𝛽
# 2
# ,
# …
# ,
# 𝛽
# 𝑝
# β
# 1
# 	​
#
# ,β
# 2
# 	​
#
# ,…,β
# p
# 	​
#
# : Regression coefficients (how much
# 𝑌
# Y changes for a one-unit change in each
# 𝑋
# 𝑖
# X
# i
# 	​
#
# , holding others constant)
#
# 𝜀
# ε: Error term (captures unexplained variation)
#
# 🔹 Purpose
#
# Multiple Linear Regression helps you:
#
# Predict the value of
# 𝑌
# Y based on several inputs.
#
# Quantify the impact of each independent variable while controlling for others.
#
# Test hypotheses about relationships between variables.
#
# 🔹 Example
#
# Suppose you want to predict a person’s annual income (
# 𝑌
# Y) based on:
#
# Years of education (
# 𝑋
# 1
# X
# 1
# 	​
#
# )
#
# Years of experience (
# 𝑋
# 2
# X
# 2
# 	​
#
# )
#
# Age (
# 𝑋
# 3
# X
# 3
# 	​
#
# )
#
# Then your model might look like:
#
# Income
# =
# 25000
# +
# 3000
# (
# Education
# )
# +
# 1500
# (
# Experience
# )
# +
# 500
# (
# Age
# )
# Income=25000+3000(Education)+1500(Experience)+500(Age)
#
# Interpretation:
#
# Each additional year of education increases income by $3,000 (holding experience and age constant).
#
# Each year of experience adds $1,500, etc.
#
# 🔹 Key Assumptions of MLR
#
# Linearity: Relationship between dependent and each independent variable is linear.
#
# Independence: Observations are independent of each other.
#
# Homoscedasticity: Constant variance of residuals.
#
# Normality: Residuals are normally distributed.
#
# No multicollinearity: Independent variables are not highly correlated with each other.
#
# 🔹 Why It’s Useful
#
# Captures real-world complexity better than simple regression.
#
# Enables control for confounding variables (e.g., measuring education’s effect on income while holding age constant).
#
# Forms the foundation for advanced models like logistic regression, time series, and machine learning regressors.
#
# 🔹 Model Evaluation Metrics
#
# Common metrics to assess model fit include:
#
# 𝑅
# 2
# R
# 2
#  and Adjusted
# 𝑅
# 2
# R
# 2
#  — measure goodness of fit
#
# F-test — checks if the model is overall significant
#
# p-values — test significance of individual predictors
#
# RMSE (Root Mean Squared Error) — measures prediction error

# %% [markdown]
# #5.What is polynomial regression, and how does it differ from linear regression?
# ans:-Polynomial Regression is a type of regression analysis that models the relationship between the independent variable(s) and the dependent variable as an nth-degree polynomial, rather than a straight line.
#
# It’s especially useful when data show a curved (nonlinear) relationship that a simple linear model can’t capture.
#
# 🔹 Definition
#
# The general form of a Polynomial Regression model (with one independent variable
# 𝑋
# X) is:
#
# 𝑌
# =
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑋
# +
# 𝛽
# 2
# 𝑋
# 2
# +
# 𝛽
# 3
# 𝑋
# 3
# +
# ⋯
# +
# 𝛽
# 𝑛
# 𝑋
# 𝑛
# +
# 𝜀
# Y=β
# 0
# 	​
#
# +β
# 1
# 	​
#
# X+β
# 2
# 	​
#
# X
# 2
# +β
# 3
# 	​
#
# X
# 3
# +⋯+β
# n
# 	​
#
# X
# n
# +ε
#
# Where:
#
# 𝑌
# Y: Dependent variable (output)
#
# 𝑋
# X: Independent variable (input)
#
# 𝛽
# 0
# ,
# 𝛽
# 1
# ,
# …
# ,
# 𝛽
# 𝑛
# β
# 0
# 	​
#
# ,β
# 1
# 	​
#
# ,…,β
# n
# 	​
#
# : Coefficients to be estimated
#
# 𝑛
# n: Degree of the polynomial
#
# 𝜀
# ε: Error term (unexplained variation)
#
# 🔹 How It Differs from Linear Regression
# Feature	Linear Regression	Polynomial Regression
# Relationship type	Linear (straight line)	Nonlinear (curved line)
# Equation form
# 𝑌
# =
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑋
# +
# 𝜀
# Y=β
# 0
# 	​
#
# +β
# 1
# 	​
#
# X+ε
# 𝑌
# =
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑋
# +
# 𝛽
# 2
# 𝑋
# 2
# +
# ⋯
# +
# 𝛽
# 𝑛
# 𝑋
# 𝑛
# +
# 𝜀
# Y=β
# 0
# 	​
#
# +β
# 1
# 	​
#
# X+β
# 2
# 	​
#
# X
# 2
# +⋯+β
# n
# 	​
#
# X
# n
# +ε
# Line shape	Straight	Curved (depends on polynomial degree)
# Flexibility	Rigid (only fits straight lines)	More flexible (can fit curves and bends)
# Complexity	Simple	Increases with polynomial degree
# Risk	Low overfitting risk	Higher overfitting risk (especially for high-degree polynomials)
# 🔹 Example
#
# Suppose you’re modeling the relationship between years of experience (X) and salary (Y).
#
# Linear Regression:
#
# Salary
# =
# 30
# ,
# 000
# +
# 5
# ,
# 000
# ×
# (
# Experience
# )
# Salary=30,000+5,000×(Experience)
#
# ➜ Fits a straight line.
#
# Polynomial Regression (degree = 2):
#
# Salary
# =
# 25
# ,
# 000
# +
# 4
# ,
# 000
# ×
# (
# Experience
# )
# +
# 150
# ×
# (
# Experience
# )
# 2
# Salary=25,000+4,000×(Experience)+150×(Experience)
# 2
#
# ➜ Fits a curved line — perhaps salaries grow faster after several years of experience.
#
# 🔹 Why Use Polynomial Regression
#
# ✅ When the data shows curvature — e.g., growth rates, learning curves, diminishing returns.
# ✅ When residuals from a linear model show patterns, suggesting a nonlinear relationship.
#
# 🔹 Important Notes
#
# Polynomial regression is still linear in parameters (the coefficients
# 𝛽
# β), even though it models nonlinear relationships — so it can still be solved using ordinary least squares (OLS).
#
# Using high-degree polynomials can lead to overfitting — the model fits noise rather than the underlying pattern.
#
# Sometimes non-polynomial nonlinear models (like exponential or logarithmic) are more appropriate.

# %% [markdown]
# #6.Implement a Python program to fit a Simple Linear Regression model to
# the following sample data:
# ● X = [1, 2, 3, 4, 5]
# ● Y = [2.1, 4.3, 6.1, 7.9, 10.2]
# Plot the regression line over the data points.
#
# ans:-

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Given data
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)  # Independent variable (reshaped to 2D)
Y = np.array([2.1, 4.3, 6.1, 7.9, 10.2])      # Dependent variable

# Create and fit the model
model = LinearRegression()
model.fit(X, Y)

# Get slope (coefficient) and intercept
slope = model.coef_[0]
intercept = model.intercept_

# Predict Y values using the regression model
Y_pred = model.predict(X)

# Print the regression equation
print(f"Regression equation: Y = {intercept:.2f} + {slope:.2f}X")

# Plot the data points
plt.scatter(X, Y, color='blue', label='Actual data points')

# Plot the regression line
plt.plot(X, Y_pred, color='red', label='Regression line')

# Add labels and legend
plt.title("Simple Linear Regression")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()

# Show the plot
plt.show()
# Out:
# Regression equation: Y = 0.18 + 1.98X

# %% [markdown]
# #7.Fit a Multiple Linear Regression model on this sample data:
# ● Area = [1200, 1500, 1800, 2000]
# ● Rooms = [2, 3, 3, 4]
# ● Price = [250000, 300000, 320000, 370000]
# Check for multicollinearity using VIF and report the results.
# ans:-

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm

# Given data
Area = [1200, 1500, 1800, 2000]
Rooms = [2, 3, 3, 4]
Price = [250000, 300000, 320000, 370000]

# Create a DataFrame
data = pd.DataFrame({
    'Area': Area,
    'Rooms': Rooms,
    'Price': Price
})

# Independent variables (predictors)
X = data[['Area', 'Rooms']]
# Dependent variable (target)
y = data['Price']

# Fit Multiple Linear Regression model
model = LinearRegression()
model.fit(X, y)

# Get coefficients and intercept
intercept = model.intercept_
coefficients = model.coef_

# Print the regression equation
print("Regression Equation:")
print(f"Price = {intercept:.2f} + ({coefficients[0]:.2f} × Area) + ({coefficients[1]:.2f} × Rooms)")

# ---------------------------
# Checking for multicollinearity using VIF
# ---------------------------
# Add constant term for VIF calculation
X_vif = sm.add_constant(X)

# Compute VIF for each feature
vif_data = pd.DataFrame()
vif_data["Feature"] = X_vif.columns
vif_data["VIF"] = [variance_inflation_factor(X_vif.values, i) for i in range(X_vif.shape[1])]

print("\nVariance Inflation Factor (VIF) Results:")
print(vif_data)
# Out:
# Regression Equation:
# Price = 103157.89 + (63.16 × Area) + (34736.84 × Rooms)
#
# Variance Inflation Factor (VIF) Results:
#   Feature        VIF
# 0   const  34.210526
# 1    Area   7.736842
# 2   Rooms   7.736842

# %% [markdown]
# #8.Implement polynomial regression on the following data:
# ● X = [1, 2, 3, 4, 5]
# 3
# ● Y = [2.2, 4.8, 7.5, 11.2, 14.7]
# Fit a 2nd-degree polynomial and plot the resulting curve.
#
# ans:-

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Given data
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
Y = np.array([2.2, 4.8, 7.5, 11.2, 14.7])

# Create polynomial features of degree 2
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# Fit the polynomial regression model
model = LinearRegression()
model.fit(X_poly, Y)

# Predict Y values using the fitted model
Y_pred = model.predict(X_poly)

# Print the polynomial equation
intercept = model.intercept_
coeffs = model.coef_
print(f"Polynomial Regression Equation:")
print(f"Y = {intercept:.2f} + ({coeffs[1]:.2f} * X) + ({coeffs[2]:.2f} * X^2)")

# Generate smooth curve for plotting
X_curve = np.linspace(1, 5, 100).reshape(-1, 1)
X_curve_poly = poly.transform(X_curve)
Y_curve = model.predict(X_curve_poly)

# Plot the data points and polynomial regression curve
plt.scatter(X, Y, color='blue', label='Actual Data Points')
plt.plot(X_curve, Y_curve, color='red', label='2nd Degree Polynomial Fit')

# Add labels, title, and legend
plt.title("Polynomial Regression (Degree = 2)")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Polynomial Regression Equation:
# Y = 0.06 + (1.94 * X) + (0.20 * X^2)

# %% [markdown]
# #9.: Create a residuals plot for a regression model trained on this data:
# ● X = [10, 20, 30, 40, 50]
# ● Y = [15, 35, 40, 50, 65]
# Assess heteroscedasticity by examining the spread of residuals.
# ans:-

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Given data
X = np.array([10, 20, 30, 40, 50]).reshape(-1, 1)
Y = np.array([15, 35, 40, 50, 65])

# Fit a simple linear regression model
model = LinearRegression()
model.fit(X, Y)

# Predict Y values
Y_pred = model.predict(X)

# Compute residuals
residuals = Y - Y_pred

# Print regression equation
print(f"Regression Equation: Y = {model.intercept_:.2f} + {model.coef_[0]:.2f}X")

# Plot residuals vs. predicted values
plt.scatter(Y_pred, residuals, color='blue', label='Residuals')
plt.axhline(y=0, color='red', linestyle='--', label='Zero Error Line')

# Add labels and title
plt.title("Residuals Plot to Assess Heteroscedasticity")
plt.xlabel("Predicted Values (Ŷ)")
plt.ylabel("Residuals (Y - Ŷ)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Regression Equation: Y = 6.50 + 1.15X

# %% [markdown]
# #10.Imagine you are a data scientist working for a real estate company. You
# need to predict house prices using features like area, number of rooms, and location.
# However, you detect heteroscedasticity and multicollinearity in your regression
# model. Explain the steps you would take to address these issues and ensure a robust
# model.
#
# ans:-Here’s a structured approach to tackling heteroscedasticity and multicollinearity when predicting house prices, written from the perspective of a data scientist:
#
# 1️⃣ Detect the Problems
#
# Before fixing issues, you must confirm them:
#
# Heteroscedasticity
#
# Check residuals vs. fitted values plots.
#
# Perform statistical tests like Breusch–Pagan or White’s test.
#
# If residuals spread increases with fitted values, heteroscedasticity exists.
#
# Multicollinearity
#
# Calculate Variance Inflation Factor (VIF) for each predictor.
#
# Correlation matrix can also reveal highly correlated features.
#
# VIF > 10 usually indicates high multicollinearity.
#
# 2️⃣ Addressing Heteroscedasticity
#
# If your residuals’ variance is not constant:
#
# a. Transform the dependent variable
#
# Apply log, square root, or Box-Cox transformation to stabilize variance:
#
# Price
# ′
# =
# log
# ⁡
# (
# Price
# )
# Price
# ′
# =log(Price)
#
# This reduces the effect of extreme values and stabilizes residuals.
#
# b. Weighted Least Squares (WLS)
#
# Assign weights inversely proportional to variance: observations with higher variance get lower weight.
#
# c. Robust standard errors
#
# Use heteroscedasticity-consistent standard errors (e.g., Huber-White).
#
# This does not fix heteroscedasticity but makes inference (t-tests, p-values) valid.
#
# 3️⃣ Addressing Multicollinearity
#
# If predictors like area and number of rooms are highly correlated:
#
# a. Remove or combine features
#
# Drop redundant variables.
#
# Combine correlated variables into a single feature (e.g., “total living space per room”).
#
# b. Use dimensionality reduction
#
# Apply Principal Component Analysis (PCA) to create uncorrelated components.
#
# c. Regularization techniques
#
# Use Ridge Regression (L2 penalty) or Lasso Regression (L1 penalty) to reduce coefficient instability caused by multicollinearity.
#
# 4️⃣ Model Validation
#
# After addressing issues:
#
# Check residual plots again to confirm homoscedasticity.
#
# Recalculate VIF or check PCA components to confirm multicollinearity is reduced.
#
# Evaluate model performance using cross-validation (e.g., k-fold CV) to ensure generalization.
#
# Track metrics like RMSE, R², Adjusted R² to ensure predictive accuracy.
#
# 5️⃣ Practical Notes
#
# Feature engineering can help: e.g., encode location properly (one-hot, target encoding) to avoid introducing multicollinearity.
#
# Keep interpretability in mind: overly complex transformations or PCA components may improve accuracy but reduce business interpretability.
#
# Document all steps: transformations, dropped features, or regularization choices.
